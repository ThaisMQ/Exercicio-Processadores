# %% [markdown]
# ___
# # <center> Exercícios Processador </center>
# ___
# ### <center> Questão 02

# %%
from PIL import Image 
Image.open("02.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=378x31>

# %% [markdown]
#  <center> A ULA(Unidade lógica e aritmética) é o componente do processador responsável por realizar manipulações matemáticas de dados solcitados pelo processador. Suas funções básicas dividem-se e são identificadas no próprio nome, podendo ser identificada a parte lógica e a parte aritmética da ULA.

# %%
Image.open("L.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=277x242>

# %% [markdown]
#  <center> A aréa lógica presente na ULA é responsável por administrar as informações via portas lógicas, a exemplo da porta AND, que realiza uma multiplicação em elementos de base binária, e a porta OR, a qual responsabiliza-se por somar tais numerais(vale a menção do input "INVA", que determina se será realizado um complemento de 2, ou seja, a subtração também pode ser realizada nessa unidade). A porta NOT funciona como um barramento, invertendo a informação contida no local. Vale ressaltar que uma ULA pode ter mais funcionalidades, determinadas pelo fabricante e por seu modelo de trabalho.

# %%
Image.open("A.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=363x327>

# %% [markdown]
#  <center> A funcionalidade aritmética contida na ULA responsabiliza-se pela manipulação de um ou mais numerais binários, como demonstrado no circuito acima, um somador completo capaz de realizar tanto a soma quanto a subtração desses algarismos. Vale lembrar que a quantidade de bits administrada pela área lógica também é determinada pelo fabricante, a exemplo de uma ULA projetada para somar dados de até 4 bits.

# %% [markdown]
# ___
# ### <center> Questão 05

# %%
Image.open("05.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=420x29>

# %%
Image.open("UC.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=291x88>

# %% [markdown]
#  <center> A unidade de controle é o componente responsável pela organização e coordenação das atividades que o processador irá realizar durante um ciclo de memória, coordenada pelos pulsos de energia que o clock transmite, ou seja, a cada "pulso" realizado pelo clock, pequenas operações são solicitadas pela UC para serem realizadas em outras áreas do processador até que o objetivo da instrução seja atingido, a exemplo de uma instrução de escrita em certa localidade da memória. Vale lembrar que o existem diversos tipos de pulsos que determinam o ritmo de um computador, o funcionamento do clock também definido pelo fabricante, como as operações realizadas durante o pico de subida ouu descida de determinado clock.

# %% [markdown]
# ___
# ### <center> Questão 07

# %%
Image.open("07.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=645x113>

# %% [markdown]
# <center> Para uma MP com células de 1 byte, temos 8 bits por célula. Como os três tipos de instrução presentes nesse computador são maiores, em números de bits, do que a célula, o PC precisará ser atualizado com mais de uma célula por ciclo. Logo:
# <center> Tipo A: Como a instrução possui 16 bits, o PC precisará ser incrementado com 2 células por vez, então:
# <center> PC <- PC + 2
# <center> Tipo B: Como a instrução possui 32 bits, o PC precisará ser incrementado com 4 células por vez, então:
# <center> PC <- PC + 4
# <center> Tipo C: Como a instrução possui 48 bits, o PC precisará ser incrementado com 6 células por vez, então:
# <center> PC <- PC + 6

# %% [markdown]
# ___
# ### <center> Questão 08

# %%
Image.open("08.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=628x42>

# %% [markdown]
# <center> Esse problema poderia ser resolvido com uma instrução específica, destinada a apenas realizar a atualização do valor no pc, de acordo com quantas células armazenam uma unidade de informação na memória.

# %% [markdown]
# ___
# ### <center> Questão 09

# %%
Image.open("09.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=628x37>

# %%
Image.open("PC.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=153x103>

# %% [markdown]
#  <center> O PC, ou CI, é o registrador responsável por controlar essa sequência de instruções, pois sua função é sempre adicionar a próxima instrução a entrar no ciclo para ser decodificada, normalmente seguinto o princípio de localidade para realizar essa busca e substituição, localizando-se na unidade de controle.

# %% [markdown]
# ___
# ### <center> Questão 10

# %%
Image.open("10.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=641x151>

# %% [markdown]
# <center> Total de ciclos de memória: 12
# <center> Ciclos de leitura: 10
# <center> Ciclos de escrita: 2
# <center> ADD Op.          R0 <- R0 + (Op.)
# <center> 1° ciclo) Atualização do RI com a próxima instrução (leitura)
# <center> 2° ciclo) Busca do operando na memória para realizar a soma com o conteúdo de R0 (leitura)
# <center> SUB Op.          (Op.) <- R0 - (Op.)
# <center> 1° ciclo) Atualização do RI com a próxima instrução (leitura)
# <center> 2° ciclo) Busca do operando na memória para realizar a subtraçã (leitura)
# <center> 3° ciclo) Atualização do conteúdo no endereço do operando (escrita)
# <center> ADD Op.1, Op.2           (Op.1) <- (Op.1) + (Op.2)
# <center> 1° ciclo) Atualização do RI com a próxima instrução (leitura)
# <center> 2° ciclo) Busca do operando Op.1 para realizar a soma (leitura)
# <center> 3° ciclo) Busca do operando Op.2 para realizar a soma (leitura)
# <center> 4° ciclo) Atualização do conteúdo no endereço do operando Op.1 (escrita)
# <center> INCR              R0 <- R0 + 1
# <center> 1° ciclo) Atualização do RI com a próxima instrução (leitura)
# <center> LDA          R0 <- (Op.)
# <center> 1° ciclo) Atualização do RI com a próxima instrução (leitura)
# <center> 2° ciclo) Busca do operando para atualizar o conteúdo de R0 (leitura)

# %% [markdown]
# ___
# ### <center> Questão 11

# %%
Image.open("11.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=638x27>

# %% [markdown]
# <center> Esse registrador seria o REM, pois sua quantidade de bits permite identificar quantas combinações de células podem ser armzenadas nessa memória, e, para saber sua capacidade completa em bits, basta ter acesso ao tamanho da célula.
# <center> Um REM de 18 bits é capaz de armazenar até 256K combinações de células. Pois 256K = 2^8 * 2^10

# %% [markdown]
# ___
# ### <center> Questão 12

# %%
Image.open("12.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=639x72>

# %%
# Total de células da memória:
Tmemoria = 2**16
# 64 = 2^6
# K = 2^10
# Total = 2^6 * 2^10 = 2^16 (bits para endereçamento)
# Conjunto de 256 instruções:
Op = 2**8
# 256 = 2^8 (Tamanho, em bits, do C.Op)
# Tamanho da célula:
celula = 8 + 16
print(f"""Como a palavra, a célula e a instrução possuem o mesmo tamanho, o tamanho do RDM é de {celula} bits, assim como o REG
Como o REM possui 16 bits, o PC(CI) também irá possuir 16 bits
Total de bits da memória: {Tmemoria} * {celula} = {Tmemoria * celula}
Ou seja: 2^16 * 24""")
# Out:
# Como a palavra, a célula e a instrução possuem o mesmo tamanho, o tamanho do RDM é de 24 bits, assim como o REG
# Como o REM possui 16 bits, o PC(CI) também irá possuir 16 bits
# Total de bits da memória: 65536 * 24 = 1572864
# Ou seja: 2^16 * 24

# %% [markdown]
# ___
# ### <center> Questão 13

# %%
Image.open("13.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=649x155>

# %%
# Letra A
print(f"""A) Como o BD possui 20 bits de tamanho: RDM -> 20 bits
Como o REM possui 16 bits de tamanho: PC(CI) -> 16 bits""")
# Letra B
print(f"""B) Sim, pois essa memória foi projetada com uma capacidade de até 16 bits no REM, porém está utilizando apenas 12 bits, pois:
4k = {2**2} * {2**10} = {2**2 * 2**10} = 2^12 bits de endereçamento para a célula""")
# Letra C
print(f"""C) Como a questão determinou que célula = instrução = palavra, e como a célula é estruturada em:
Célula = Bits para o C.Op + Bits de endereçamento/operando)
20 bits = Bits para o C.Op + 16(REM)
Logo, para o C.Op restam 4 bits, logo:
2^4 = {2**4} instruções de máquina""")
# Out:
# A) Como o BD possui 20 bits de tamanho: RDM -> 20 bits
# Como o REM possui 16 bits de tamanho: PC(CI) -> 16 bits
# B) Sim, pois essa memória foi projetada com uma capacidade de até 16 bits no REM, porém está utilizando apenas 12 bits, pois:
# 4k = 4 * 1024 = 4096 = 2^12 bits de endereçamento para a célula
# C) Como a questão determinou que célula = instrução = palavra, e como a célula é estruturada em:
# Célula = Bits para o C.Op + Bits de endereçamento/operando)
# 20 bits = Bits para o C.Op + 16(REM)
# Logo, para o C.Op restam 4 bits, logo:
# 2^4 = 16 instruções de máquina

# %% [markdown]
# ___
# ### <center> Questão 14

# %%
Image.open("14.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=650x323>

# %%
# conjunto de 128 instruções de máquina:
Cop = 2**7
# 128 = 2^7 (7bits para o C.Op)
# Se a memória possui 512 palavras e palavra = célula =  instrução, o número de células:
Ncelulas = 2**9
# 512 = 2^9 (endereçamento)
# Total de bits da célula = C.Op + Endereçamento
Tcelula = 7 + 9
# Letra A
print(f'''A) Bits para o REM e PC(CI): 9 bits
Bits para o RDM e RI: {Tcelula}''')
# Letra B
print(f'''B) Capacidade da memória: 2^9 * {Tcelula} = {Ncelulas * Tcelula}
Ou seja: 2^9 * 2^4 = 2^13 = 8Kbits de capacidade
Em bytes: 2^13/2^3 = {2**13/2**3}
Ou seja: 2^10 = 1Kbytes de capacidade''')
# Para uma instrução de 17 bits:
# Letra C
print(f'''C) Mantendo os 9 bits do REM e com uma instrução de 17 bits, teremos um C.op de 8 bits, logo:
Nova quantidade de instruções: 2^8 = {2**8}, a quantidade de novas instruções criadas será de: {2**8 - 2**7} instruções''')
# Out:
# A) Bits para o REM e PC(CI): 9 bits
# Bits para o RDM e RI: 16
# B) Capacidade da memória: 2^9 * 16 = 8192
# Ou seja: 2^9 * 2^4 = 2^13 = 8Kbits de capacidade
# Em bytes: 2^13/2^3 = 1024.0
# Ou seja: 2^10 = 1Kbytes de capacidade
# C) Mantendo os 9 bits do REM e com uma instrução de 17 bits, teremos um C.op de 8 bits, logo:
# Nova quantidade de instruções: 2^8 = 256, a quantidade de novas instruções criadas será de: 128 instruções

# %% [markdown]
# ___
# ### <center> Questão 15

# %%
Image.open("15.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=632x57>

# %% [markdown]
# <center> O conceito de microcomptador aplicado aqui faz referência a ULA de determinado computador, e como uma ULA opera utilizando-se das palavras fornecidas, a expressão utilizada na questão está direcionada ao tamanho da palavra de determinado processador. Ou seja, o microcomputador A é um micro de 8 bits, sua palavra possui 8 bits de tamanho, enquanto o microcomputador B possui palavras de 16 bits.
# <center> O conceito de célula diz repeito a uma única unidade de dado do computador, que pode ser composta por um ou mais bits, enquanto a palavra refere-se a uma unidade de informação, e essa pode ser composta por uma ou mais células. Por exemplo:
# <center> O microcomputador B tem palavras de 16 bits, e pode ter células de 4 bits, então cada palavra sertia formada por 4 células, para compor uma única informação.

# %% [markdown]
# ___
# ### <center> Questão 16

# %%
Image.open("16.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=644x156>

# %%
# Tamanho da instrução:
# Letra A
print("""A) A questão fornece o tamanho do RI, o qual é o mesmo da instrução: 38bits""")
Operandos = 16 + 16
Cop = 38 - Operandos
# Letra B
print(f"""B) Formato da instrução = C.Op + Op.1 + Op.2
38 bits = C.Op + 16bits + 16bits
Logo, o tamanho do C.Op equivale a: {Cop} bits""")
# Letra C
print(f"""C) Como o PC possui um máximo de 16 bits, essa memória pode ser expandida até a totalidade de endereçamento permitida, logo:
2^16 = {2**6} * {2**10} = {2**6 * 2**10} = 2^6 * 2^10 = 64Kbytes""")
# Out:
# A) A questão fornece o tamanho do RI, o qual é o mesmo da instrução: 38bits
# B) Formato da instrução = C.Op + Op.1 + Op.2
# 38 bits = C.Op + 16bits + 16bits
# Logo, o tamanho do C.Op equivale a: 6 bits
# C) Como o PC possui um máximo de 16 bits, essa memória pode ser expandida até a totalidade de endereçamento permitida, logo:
# 2^16 = 64 * 1024 = 65536 = 2^6 * 2^10 = 64Kbytes

# %% [markdown]
# ___
# ### <center> Questão 17

# %%
Image.open("17.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=638x455>

# %%
# Capacidade total 
# Letra A, B e C 
print(f"""A) Capacidade total da memória = Total de células x Tamanho em bits da célula
Capacidade total da memória = {2**8} * {2**4} = {2**8 * 2**4} = 2^12 = 4K
B) Se o conteúdo A5 estiver no PC, a instrução executada será a CB05
C) Se o processo de leitura for requisitado no endereço FD, o RDM irá estar com o conteúdo 4040""")
# Out:
# A) Capacidade total da memória = Total de células x Tamanho em bits da célula
# Capacidade total da memória = 256 * 16 = 4096 = 2^12 = 4K
# B) Se o conteúdo A5 estiver no PC, a instrução executada será a CB05
# C) Se o processo de leitura for requisitado no endereço FD, o RDM irá estar com o conteúdo 4040

# %% [markdown]
# ___
# ### <center> Questão 18

# %%
Image.open("18.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=487x23>

# %% [markdown]
# <center> No processamento sequencial, apenas uma informação por vez é alterada, lida ou escrita pelo processador até sua finalização, enquanto no método pipeline, assim que um componente do processador fica livre de uma informação, outra ocupa seu lugar, otimizando o tempo de resposta em diversas instâncias.

# %% [markdown]
# ___
# ### <center> Questão 19

# %%
Image.open("19.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=645x378>

# %% [markdown]
# <center> A) Cada operando irá possuir 32 bits de largura, por conta do tamanho do PC, fornecido pela questão
# <center> B) Essa memória possui um endereçamento de 2^32, ou seja: 2^2 * 2^30 = 4G de endereçamento
# <center> C) Os registradores para valores inteiros também precisam de 32 bits para armazenar.

# %% [markdown]
# ___
# ### <center> Questão 20

# %%
Image.open("20.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x73>

# %% [markdown]
# <center> Serão necessários, no mínimo, 8 bits de entrada para representar o conjunto de 197 saídas de instrução projetadas para essa memória.

# %% [markdown]
# ___
# ### <center> Questão 22

# %%
Image.open("22.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=651x491>

# %% [markdown]
# <center> A) A largura do campo C.Op é de 8 bits, pois a tabela fornece dois algarismos em base 16, ou seja, cada algarismo precisa de 4 bits para ser representado.
# <center> B) A largura do campo Reg é de 4 bits, pois a questão fornece que exustem 16 conjuntos, ou seja, 2^4.
# <center> C) No C.Op 11 será necessário apenas um acesso na memória, para buscar a instrução indiciada pelo PC.
# <center> No C.Op 21 serão necessários dois acessos, um para buscar a instrução contida na memória e outra para buscar o operando contido no endereço fornecido pela instrução.
